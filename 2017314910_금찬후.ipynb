# %% [markdown]
# ## Task
# - Complete **isHappy** function following the description below
#
# ### Happy Number
# Write an algorithm to determine if a number **n** is happy.
#
# A **happy number** is a number defined by the following process:
#
# * Starting with any positive integer, replace the number by the sum of the squares of its digits.
# * Repeat the process until the number equals 1 (where it will stay), or it **loops endlessly in a cycle** which does not include 1.
# * Those numbers for which this process **ends in 1** are happy.
#
# Return **true** if n is a happy number, and **false** if not.
#
# Constraints:
# 1 <= n <= $2^{31}$ - 1

# %%
def isHappy(n):
  #pass
  l = []
  x = n
  while(x not in l):
    l.append(x)
    #print('list: ',l)
    s = 0
    while (x >= 10):
      r = x%10
      #print('remainder: ',r)
      x = x//10
      #print('quotient: ',x)
      s = s + r*r
      #print('mid sum: ', s)
    s = s + x*x
    #print('final sum: ', s)
    x = s
    if (x == pow(10,0) or x == pow(10,1) or x == pow(10,2) or x == pow(10,3) or x == pow(10,4) or x == pow(10,5) or x == pow(10,6) or x == pow(10,7) or x == pow(10,8) or x == pow(10,9)):
      return 'true'
  return 'false'

print(isHappy(19))
print(isHappy(2))
# Out:
# true
# false

# %% [markdown]
# **Testcase 1.**
#
# **Input**: n = 19
#
# **Output**: True
#
# **Explanation**:
#
# $1^2 + 9^2 = 82$
#
# $8^2 + 2^2 = 68$
#
# $6^2 + 2^2 = 100$
#
# $1^2 + 0^2 + 0^2 = 1$

# %% [markdown]
# **Testcase 2.**
#
# **Input**: n = 2
#
# **Output**: False
